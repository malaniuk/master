# %%
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import numpy as np
from typing import Dict, List, Optional
from datetime import datetime
import pandas as pd
from collections import defaultdict

class AnomalyDetector:
    def __init__(self, data_loader, transaction_analyzer):
        self.data_loader = data_loader
        self.transaction_analyzer = transaction_analyzer
        self.isolation_forest = None
        self.scaler = StandardScaler()
        self.global_features = None
        self.contract_models = None
        self.trained = False

    def prepare_global_features(self):
        """Підготовка характеристик для звичайних гаманців"""
        features = []
        addresses = []
        feature_columns = [
            'tx_count', 
            'avg_value', 
            'std_value', 
            'unique_contacts',
            'avg_time_diff', 
            'std_time_diff', 
            'contract_interaction_ratio'
        ]
    
        # Беремо тільки не-контрактні адреси
        for address in self.data_loader.get_non_contract_addresses():
            feature_vector = self._extract_wallet_features(address)
            if feature_vector:
                features.append(feature_vector)
                addresses.append(address)
            
        if features:
            self.global_features = pd.DataFrame(
                features,
                columns=feature_columns,  # Додаємо назви колонок
                index=addresses
            )
            
    def train_model(self):
        """Тренування моделей для виявлення аномалій"""
        if self.global_features is None:
            self.prepare_global_features()
            
        # Модель для звичайних гаманців
        scaled_features = self.scaler.fit_transform(self.global_features)
        self.isolation_forest = IsolationForest(
            contamination=0.1,
            random_state=42
        )
        self.isolation_forest.fit(scaled_features)
        
        # Підготовка моделей для різних типів контрактів
        self._prepare_contract_models()
        
        self.trained = True
        
    def detect_anomalies(self, address: str) -> Dict:
        """Виявлення аномалій для адреси"""
        if not self.trained:
            self.train_model()
            
        # Визначаємо тип адреси
        if self.data_loader.is_contract(address):
            return self._detect_contract_anomalies(address)
        else:
            return self._detect_wallet_anomalies(address)
            
    def _prepare_contract_models(self):
        """Підготовка моделей для аналізу контрактів"""
        contract_features = defaultdict(list)
        contract_addresses = defaultdict(list)
        
        # Збір характеристик контрактів
        for address in self.data_loader.get_contract_addresses():
            features = self._extract_contract_features(address)
            if features:
                label = self.data_loader.get_address_info(address).get('label', 'unknown')
                contract_features[label].append(features)
                contract_addresses[label].append(address)
                
        # Створення окремих моделей для кожного типу контракту
        self.contract_models = {}
        for label in contract_features:
            if len(contract_features[label]) > 10:  # Мінімальна кількість для навчання
                features_array = np.array(contract_features[label])
                scaler = StandardScaler()
                scaled_features = scaler.fit_transform(features_array)
                
                model = IsolationForest(contamination=0.1, random_state=42)
                model.fit(scaled_features)
                
                self.contract_models[label] = {
                    'model': model,
                    'scaler': scaler
                }
                
    def _extract_wallet_features(self, address: str) -> Optional[List[float]]:
        """Витяг характеристик для звичайного гаманця"""
        transactions = self.data_loader.get_node_transactions(address)
        if not transactions:
            return None
            
        # Базові метрики
        tx_values = [float(tx['value$']) for tx in transactions]
        timestamps = [datetime.strptime(tx['timestamp'], '%Y-%m-%dT%H:%M:%S.%fZ') 
                     for tx in transactions]
        
        # Часові різниці
        time_diffs = [(timestamps[i] - timestamps[i-1]).total_seconds() / 3600 
                     for i in range(1, len(timestamps))]
        
        # Взаємодії з контрактами
        contract_interactions = sum(1 for tx in transactions 
                                 if self.data_loader.is_contract(tx['to']))
        
        # Вектор характеристик
        return [
            len(transactions),                          # Кількість транзакцій
            np.mean(tx_values),                        # Середнє значення
            np.std(tx_values),                         # Стандартне відхилення
            len(set(tx['to'] for tx in transactions)), # Унікальні контакти
            np.mean(time_diffs) if time_diffs else 0,  # Середній час між транзакціями
            np.std(time_diffs) if time_diffs else 0,   # Стандартне відхилення часу
            contract_interactions / len(transactions)   # Частка взаємодій з контрактами
        ]
        
    def _extract_contract_features(self, address: str) -> Optional[List[float]]:
        """Витяг характеристик для контракту"""
        transactions = self.data_loader.get_node_transactions(address)
        if not transactions:
            return None
            
        # Вхідні та вихідні транзакції
        incoming = [tx for tx in transactions if tx['to'] == address]
        outgoing = [tx for tx in transactions if tx['from'] == address]
        
        # Значення транзакцій
        in_values = [float(tx['value$']) for tx in incoming]
        out_values = [float(tx['value$']) for tx in outgoing]
        
        return [
            len(incoming),                            # Кількість вхідних
            len(outgoing),                           # Кількість вихідних
            np.mean(in_values) if in_values else 0,  # Середнє вхідне значення
            np.mean(out_values) if out_values else 0,# Середнє вихідне значення
            np.std(in_values) if in_values else 0,   # Стандартне відхилення вхідних
            np.std(out_values) if out_values else 0, # Стандартне відхилення вихідних
            len(set(tx['from'] for tx in incoming)), # Унікальні відправники
            len(set(tx['to'] for tx in outgoing))    # Унікальні отримувачі
        ]
        
    def _detect_wallet_anomalies(self, address: str) -> Dict:
        """Виявлення аномалій для звичайного гаманця"""
        features = self._extract_wallet_features(address)
        if not features:
            return {'anomalies': [], 'anomaly_score': 0}
            
        # Передбачення аномальності
        scaled_features = self.scaler.transform([features])
        is_anomaly = self.isolation_forest.predict(scaled_features)[0] == -1
        anomaly_score = -self.isolation_forest.score_samples(scaled_features)[0]
        
        # Збір аномалій
        anomalies = []
        if is_anomaly:
            anomalies.extend(self._detect_value_anomalies(address))
            anomalies.extend(self._detect_temporal_anomalies(address))
            anomalies.extend(self._detect_pattern_anomalies(address))
            
        return {
            'anomalies': anomalies,
            'anomaly_score': float(anomaly_score),
            'is_anomaly': is_anomaly
        }
        
    def _detect_contract_anomalies(self, address: str) -> Dict:
        """Виявлення аномалій для контракту"""
        features = self._extract_contract_features(address)
        if not features:
            return {'anomalies': [], 'anomaly_score': 0}
            
        label = self.data_loader.get_address_info(address).get('label', 'unknown')
        
        # Якщо є модель для цього типу контракту
        if label in self.contract_models:
            model_data = self.contract_models[label]
            scaled_features = model_data['scaler'].transform([features])
            is_anomaly = model_data['model'].predict(scaled_features)[0] == -1
            anomaly_score = -model_data['model'].score_samples(scaled_features)[0]
        else:
            is_anomaly = False
            anomaly_score = 0
            
        # Специфічні аномалії для контрактів
        anomalies = []
        if is_anomaly:
            anomalies.extend(self._detect_contract_specific_anomalies(address))
            
        return {
            'anomalies': anomalies,
            'anomaly_score': float(anomaly_score),
            'is_anomaly': is_anomaly,
            'contract_type': label
        }
        
    def _detect_contract_specific_anomalies(self, address: str) -> List[Dict]:
        """Виявлення специфічних аномалій для контрактів"""
        anomalies = []
        transactions = self.data_loader.get_node_transactions(address)
        
        # Аналіз вхідних/вихідних патернів
        incoming = defaultdict(list)
        outgoing = defaultdict(list)
        
        for tx in transactions:
            if tx['to'] == address:
                incoming[tx['from']].append(float(tx['value$']))
            else:
                outgoing[tx['to']].append(float(tx['value$']))
                
        # Перевірка на незвичні патерни взаємодії
        for sender, values in incoming.items():
            if len(values) > 100 and np.std(values) / np.mean(values) > 2:
                anomalies.append({
                    'type': 'contract_interaction',
                    'subtype': 'unusual_input_pattern',
                    'details': {
                        'sender': sender,
                        'interaction_count': len(values),
                        'value_volatility': np.std(values) / np.mean(values)
                    }
                })
                
        return anomalies
        
    def _detect_value_anomalies(self, address: str) -> List[Dict]:
        """Виявлення аномалій в значеннях транзакцій"""
        transactions = self.data_loader.get_node_transactions(address)
        anomalies = []
        
        if not transactions:
            return anomalies
            
        values = [float(tx['value$']) for tx in transactions]
        mean_value = np.mean(values)
        std_value = np.std(values)
        
        for tx in transactions:
            value = float(tx['value$'])
            z_score = (value - mean_value) / std_value if std_value > 0 else 0
            
            if abs(z_score) > 3:  # 3 сигми
                anomalies.append({
                    'type': 'value',
                    'subtype': 'extreme_value',
                    'timestamp': tx['timestamp'],
                    'details': {
                        'value': value,
                        'z_score': z_score,
                        'to': tx['to'],
                        'is_contract': self.data_loader.is_contract(tx['to'])
                    }
                })
                
        return anomalies
        
    def _detect_temporal_anomalies(self, address: str) -> List[Dict]:
        """Виявлення часових аномалій"""
        transactions = self.data_loader.get_node_transactions(address)
        anomalies = []
        
        if len(transactions) < 2:
            return anomalies
            
        timestamps = [datetime.strptime(tx['timestamp'], '%Y-%m-%dT%H:%M:%S.%fZ') 
                     for tx in transactions]
        time_diffs = [(timestamps[i] - timestamps[i-1]).total_seconds() / 3600 
                     for i in range(1, len(timestamps))]
        
        mean_diff = np.mean(time_diffs)
        std_diff = np.std(time_diffs)
        
        for i, diff in enumerate(time_diffs, 1):
            z_score = (diff - mean_diff) / std_diff if std_diff > 0 else 0
            
            if abs(z_score) > 3:
                anomalies.append({
                    'type': 'temporal',
                    'subtype': 'unusual_timing',
                    'timestamp': transactions[i]['timestamp'],
                    'details': {
                        'time_diff': diff,
                        'z_score': z_score,
                        'usual_time_diff': mean_diff
                    }
                })
                
        return anomalies
        
    def _detect_pattern_anomalies(self, address: str) -> List[Dict]:
        """Виявлення аномалій в патернах поведінки"""
        patterns = self.transaction_analyzer.analyze_wallet_patterns(address)
        anomalies = []
        
        if not patterns:
            return anomalies
            
        # Аномалії в послідовностях
        if 'sequence' in patterns:
            seq_patterns = patterns['sequence']
            if seq_patterns['avg_sequence_length'] > 5:  # Незвично довгі послідовності
                anomalies.append({
                    'type': 'pattern',
                    'subtype': 'long_sequence',
                    'details': {
                        'avg_length': seq_patterns['avg_sequence_length']
                    }
                })
                
        # Аномалії в контрактних взаємодіях
        if 'contract_usage' in patterns:
            contract_usage = patterns['contract_usage']
            if contract_usage['unique_contracts'] > 20:  # Багато різних контрактів
                anomalies.append({
                    'type': 'pattern',
                    'subtype': 'high_contract_diversity',
                    'details': {
                        'unique_contracts': contract_usage['unique_contracts']
                    }
                })
                
        return anomalies

# %%
# %run data_loader.ipynb
# %run transaction_pattern.ipynb

import json
from datetime import datetime
from pprint import pprint

def analyze_anomalies(detector, address: str):
    """Детальний аналіз аномалій для адреси"""
    print(f"\nAnalyzing anomalies for address: {address}")
    print("=" * 50)
    
    # Отримуємо результати аналізу
    results = detector.detect_anomalies(address)
    
    # Базова інформація
    print(f"\nAnomaly Score: {results['anomaly_score']:.4f}")
    print(f"Is Anomalous: {results['is_anomaly']}")
    
    if 'contract_type' in results:
        print(f"Contract Type: {results['contract_type']}")
        
    # Деталізація аномалій
    if results['anomalies']:
        print("\nDetected Anomalies:")
        anomalies_by_type = {}
        
        # Групуємо аномалії за типами
        for anomaly in results['anomalies']:
            anomaly_type = anomaly['type']
            if anomaly_type not in anomalies_by_type:
                anomalies_by_type[anomaly_type] = []
            anomalies_by_type[anomaly_type].append(anomaly)
            
        # Виводимо аномалії по групах
        for anomaly_type, anomalies in anomalies_by_type.items():
            print(f"\n{anomaly_type.upper()} ANOMALIES:")
            for anomaly in anomalies:
                print(f"\nSubtype: {anomaly['subtype']}")
                if 'timestamp' in anomaly:
                    print(f"Time: {anomaly['timestamp']}")
                print("Details:")
                pprint(anomaly['details'])
    else:
        print("\nNo anomalies detected")
        
    return results

def test():
    # Ініціалізація
    print("Initializing components...")
    loader = DataLoader()
    loader.load_addresses("data/addresses.json")
    loader.load_tokens("data/tokens.json")
    loader.load_nodes("data/nodes_new.csv")
    
    tx_analyzer = TransactionPatternAnalyzer(loader)
    tx_analyzer.build_interaction_graph()
    
    detector = AnomalyDetector(loader, tx_analyzer)
    
    # Підготовка та тренування моделі
    print("Preparing and training models...")
    detector.prepare_global_features()
    detector.train_model()
    
    # Аналіз різних типів адрес
    contract_address = "0x9696f59e4d72e237be84ffd425dcad154bf96976"

    addresses = [
        '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1', # binance
        '0x39cf2e49ea4d620e77d67088a8d815348e0abdf6', # normal
        '0xa1b1bbb8070df2450810b8eb2425d543cfcef79b', # fund
    ]

    def count_anomalies_by_type(results):
        counts = defaultdict(int)
        for anomaly in results['anomalies']:
            counts[anomaly['type']] += 1
        return dict(counts)
    
    # Аналіз контракту
    print("\nAnalyzing contract...")
    contract_results = analyze_anomalies(detector, contract_address)
    contract_anomaly_counts = count_anomalies_by_type(contract_results)
    print("\nContract anomalies by type:")
    pprint(contract_anomaly_counts)

    

    for address in addresses:
        # Аналіз гаманця
        print("\nAnalyzing wallet...")
        wallet_results = analyze_anomalies(detector, address)
    
        # Порівняльний аналіз
        print("\nComparative Analysis:")
        print("-" * 30)
        print(f"Contract Anomaly Score: {contract_results['anomaly_score']:.4f}")
        print(f"Wallet Anomaly Score: {wallet_results['anomaly_score']:.4f}")

        wallet_anomaly_counts = count_anomalies_by_type(wallet_results)
    
        print("\nWallet anomalies by type:")
        pprint(wallet_anomaly_counts)
    
        # Додатковий аналіз для гаманця
        if not loader.is_contract(address):
            # Часові патерни аномалій
            temporal_anomalies = [
                a for a in wallet_results['anomalies']
                if a['type'] == 'temporal'
            ]
            if temporal_anomalies:
                print("\nTemporal Anomaly Analysis:")
                for anomaly in temporal_anomalies:
                    print(f"\nTimestamp: {anomaly['timestamp']}")
                    print(f"Time difference: {anomaly['details']['time_diff']:.2f} hours")
                    print(f"Z-score: {anomaly['details']['z_score']:.2f}")
        
            # Аномалії значень
            value_anomalies = [
                a for a in wallet_results['anomalies']
                if a['type'] == 'value'
            ]
            if value_anomalies:
                print("\nValue Anomaly Analysis:")
                for anomaly in value_anomalies:
                    print(f"\nValue: {anomaly['details']['value']}")
                    print(f"Z-score: {anomaly['details']['z_score']:.2f}")
                    print(f"To contract: {anomaly['details']['is_contract']}")

# %%
test()
# Out:
# Initializing components...
# Loaded 1733 addresses
# Loaded 5825 tokens
# Loaded 1025 nodes
# Contracts: 51
# Non-contracts: 974
# Preparing and training models...
#
# Analyzing contract...
#
# Analyzing anomalies for address: 0x9696f59e4d72e237be84ffd425dcad154bf96976
# ==================================================
#
# Anomaly Score: 0.5541
# Is Anomalous: True
#
# Detected Anomalies:
#
# VALUE ANOMALIES:
#
# Subtype: extreme_value
# Time: 2021-05-27T23:09:02.025Z
# Details:
# {'is_contract': False,
#  'to': '0x96181a7e0195cef37f71c6442d8a2df146d2a347',
#  'value': 854000.0,
#  'z_score': 4.187555379264425}
#
# Subtype: extreme_value
# Time: 2021-05-29T21:02:02.991Z
# Details:
# {'is_contract': False,
#  'to': '0x3ba76787d7d9bd0d40370905f746e75d1f0e578e',
#  'value': 654185.0,
#  'z_score': 3.1083255811949293}
#
# Subtype: extreme_value
# Time: 2021-05-30T01:45:57.486Z
# Details:
# {'is_contract': False,
#  'to': '0x5d2d9201f8c2a42c5ddb06e70de1d49e01e8281b',
#  'value': 637000.0,
#  'z_score': 3.0155069035189577}
#
# Subtype: extreme_value
# Time: 2021-06-23T16:40:55.236Z
# Details:
# {'is_contract': False,
#  'to': '0xecc64e3f8126d270d6b4727614c77b18155f3253',
#  'value': 951335.0,
#  'z_score': 4.713275832659287}
#
# Subtype: extreme_value
# Time: 2021-07-10T14:54:59.779Z
# Details:
# {'is_contract': False,
#  'to': '0xf9f012cb18205d62166823d3fb96ca497d56aaf5',
#  'value': 815447.5735,
#  'z_score': 3.9793281317270326}
#
# Subtype: extreme_value
# Time: 2021-07-15T16:25:17.144Z
# Details:
# {'is_contract': False,
#  'to': '0x1bf621aa9cee3f6154881c25041bb39aed4ca7cc',
#  'value': 636906.893,
#  'z_score': 3.0150040191068324}
#
# Subtype: extreme_value
# Time: 2021-07-18T10:39:34.883Z
# Details:
# {'is_contract': False,
#  'to': '0x84ddd4b940bb071f3190e73a6e981b9f5786c1b1',
#  'value': 714000.0,
#  'z_score': 3.431395072331865}
#
# Subtype: extreme_value
# Time: 2021-08-09T10:13:55.738Z
# Details:
# {'is_contract': False,
#  'to': '0x24763d2d9ee73e260bc92972298691e93794e191',
#  'value': 669054.3685,
#  'z_score': 3.188637197258167}
#
# Subtype: extreme_value
# Time: 2021-08-13T06:39:53.685Z
# Details:
# {'is_contract': False,
#  'to': '0x5b3b7e243c44a38a9930b53c79ab1f523161b643',
#  'value': 679000.0,
#  'z_score': 3.2423549955987254}
#
# Subtype: extreme_value
# Time: 2021-08-13T23:33:51.465Z
# Details:
# {'is_contract': False,
#  'to': '0xdaa3f729648e6d6e2965174984748ae3947f0b09',
#  'value': 680930.6595,
#  'z_score': 3.2527827675994554}
#
# Subtype: extreme_value
# Time: 2021-08-14T09:35:41.276Z
# Details:
# {'is_contract': False,
#  'to': '0xce04f4c6a22e8196064f12b041dd2cc2b6aa2818',
#  'value': 840000.0,
#  'z_score': 4.111939348571169}
#
# Subtype: extreme_value
# Time: 2021-08-21T19:33:44.442Z
# Details:
# {'is_contract': False,
#  'to': '0x392d04e6ef99a3857958d9a44b10bdf9b8aba2d0',
#  'value': 653357.6525,
#  'z_score': 3.1038569573410726}
#
# Subtype: extreme_value
# Time: 2021-09-11T17:52:59.665Z
# Details:
# {'is_contract': False,
#  'to': '0x0c252390cbfff16e6a810717754d7f8403617887',
#  'value': 651000.0,
#  'z_score': 3.0911229342122133}
#
# Subtype: extreme_value
# Time: 2021-09-19T11:14:22.157Z
# Details:
# {'is_contract': False,
#  'to': '0x2a9460b205f1943544b3023b0bc3cf16fe403212',
#  'value': 679000.0,
#  'z_score': 3.2423549955987254}
#
# Subtype: extreme_value
# Time: 2021-09-21T08:46:59.671Z
# Details:
# {'is_contract': False,
#  'to': '0xce04f4c6a22e8196064f12b041dd2cc2b6aa2818',
#  'value': 946624.805,
#  'z_score': 4.687835386252772}
#
# Subtype: extreme_value
# Time: 2021-09-24T16:21:40.824Z
# Details:
# {'is_contract': False,
#  'to': '0x335e15dbf54ae0ac953ecd32e25438e2e491b8c2',
#  'value': 742805.0,
#  'z_score': 3.5869750554832396}
#
# Subtype: extreme_value
# Time: 2021-10-08T19:56:39.630Z
# Details:
# {'is_contract': False,
#  'to': '0x16984b2627f4b49f3a014aa9e3c8d367b5fabcde',
#  'value': 869574.4435,
#  'z_score': 4.271675207673453}
#
# Subtype: extreme_value
# Time: 2021-10-12T11:32:35.332Z
# Details:
# {'is_contract': False,
#  'to': '0xb60199d88ab641daad15a1d7af5786b43fa796aa',
#  'value': 700000.0,
#  'z_score': 3.3557790416386095}
#
# Subtype: extreme_value
# Time: 2021-10-19T11:41:52.164Z
# Details:
# {'is_contract': False,
#  'to': '0x234c4a3584e47e13a98dc9d7067908eaf974e323',
#  'value': 996711.73,
#  'z_score': 4.958362133262114}
#
# Subtype: extreme_value
# Time: 2021-10-23T12:05:20.273Z
# Details:
# {'is_contract': False,
#  'to': '0xd86b1c0de6772dd086364d02271fd82873220e3d',
#  'value': 959000.0,
#  'z_score': 4.7546756094638445}
#
# Subtype: extreme_value
# Time: 2021-11-02T04:37:33.777Z
# Details:
# {'is_contract': False,
#  'to': '0x463c243f40dad4ce8daffe384e9e1d2c661c3dbd',
#  'value': 679000.0,
#  'z_score': 3.2423549955987254}
#
# Subtype: extreme_value
# Time: 2021-11-02T07:18:33.054Z
# Details:
# {'is_contract': False,
#  'to': '0x1cd89ee8e052b27ca26c8f5703d9149663f52b9c',
#  'value': 945000.0,
#  'z_score': 4.679059578770588}
#
# Subtype: extreme_value
# Time: 2021-11-05T09:35:36.147Z
# Details:
# {'is_contract': False,
#  'to': '0x102dff147b89a766e377e50dd4cd7b6e3d3c9b79',
#  'value': 854000.0,
#  'z_score': 4.187555379264425}
#
# Subtype: extreme_value
# Time: 2021-11-12T22:19:17.302Z
# Details:
# {'is_contract': False,
#  'to': '0x815447eb4174ae3926532f0d556c7f280449a688',
#  'value': 707227.941,
#  'z_score': 3.3948181993889697}
#
# Subtype: extreme_value
# Time: 2021-11-24T13:56:45.177Z
# Details:
# {'is_contract': False,
#  'to': '0xecc64e3f8126d270d6b4727614c77b18155f3253',
#  'value': 954275.0,
#  'z_score': 4.729155199104871}
#
# Subtype: extreme_value
# Time: 2022-01-01T22:14:18.385Z
# Details:
# {'is_contract': False,
#  'to': '0x619511ad59f8e79ee4ce8c4c26d37c18d47b2ae0',
#  'value': 658504.658,
#  'z_score': 3.1316566806172417}
#
# Subtype: extreme_value
# Time: 2022-01-12T12:28:03.279Z
# Details:
# {'is_contract': False,
#  'to': '0x2f576885a65e3d2818d1a7a99be40cdee395d3df',
#  'value': 892850.0,
#  'z_score': 4.39738986443821}
#
# Subtype: extreme_value
# Time: 2022-01-30T20:16:47.372Z
# Details:
# {'is_contract': False,
#  'to': '0x92ca39aea8012a7d5621052f4e932db04a15d678',
#  'value': 682533.439,
#  'z_score': 3.2614396121613503}
#
# Subtype: extreme_value
# Time: 2022-01-30T23:25:22.951Z
# Details:
# {'is_contract': False,
#  'to': '0x23ed008d057dc810ed813a395e2794ec54d7d368',
#  'value': 712130.587,
#  'z_score': 3.4212981015614106}
#
# Subtype: extreme_value
# Time: 2022-02-02T06:58:34.137Z
# Details:
# {'is_contract': False,
#  'to': '0xe8d3f259911e26a185eb7bd54940f676cc829a88',
#  'value': 679003.5,
#  'z_score': 3.242373899606399}
#
# Subtype: extreme_value
# Time: 2022-02-14T02:08:55.481Z
# Details:
# {'is_contract': False,
#  'to': '0x1aeae810236aff036a988e9ccf45528392377f02',
#  'value': 637000.0,
#  'z_score': 3.0155069035189577}
#
# Subtype: extreme_value
# Time: 2022-02-20T12:12:23.126Z
# Details:
# {'is_contract': False,
#  'to': '0x185f5311f2617c5732f0bbb666bc10df2514bc77',
#  'value': 768425.0,
#  'z_score': 3.725352391651898}
#
# Subtype: extreme_value
# Time: 2022-02-24T18:59:26.901Z
# Details:
# {'is_contract': False,
#  'to': '0x6947c7de4bf6da7ebdcfae05ee1b0dd66b047a11',
#  'value': 906746.1585,
#  'z_score': 4.472445032127807}
#
# Subtype: extreme_value
# Time: 2022-02-26T22:44:06.580Z
# Details:
# {'is_contract': False,
#  'to': '0x8849cc00eeb1505b39656b643871aba4e7d3cd63',
#  'value': 952677.39,
#  'z_score': 4.720526275762309}
#
# Subtype: extreme_value
# Time: 2022-02-27T19:23:19.261Z
# Details:
# {'is_contract': False,
#  'to': '0x4053900e07c4c1c3ad72bea7e46b6df020ec4fe0',
#  'value': 959910.0,
#  'z_score': 4.759590651458907}
#
# Subtype: extreme_value
# Time: 2022-03-22T23:24:39.137Z
# Details:
# {'is_contract': False,
#  'to': '0xfe6f02869bf7fea6dbf27155757cc76e016d3d01',
#  'value': 707000.0,
#  'z_score': 3.393587056985237}
#
# Subtype: extreme_value
# Time: 2022-04-10T21:43:07.416Z
# Details:
# {'is_contract': False,
#  'to': '0x4b5d5cfc9d4a5468fcc06663ee4ef4c8cfa96a40',
#  'value': 769994.75,
#  'z_score': 3.733830839093379}
#
# Subtype: extreme_value
# Time: 2022-06-13T08:19:38.304Z
# Details:
# {'is_contract': False,
#  'to': '0x1b3bb4749f684a5bcd8c636f80ee024fd2281562',
#  'value': 694976.877,
#  'z_score': 3.3286484257140376}
#
# Subtype: extreme_value
# Time: 2022-06-18T01:00:17.705Z
# Details:
# {'is_contract': False,
#  'to': '0x4547e62b8d9665da09152fd0b8607afdc7d02159',
#  'value': 700000.0,
#  'z_score': 3.3557790416386095}
#
# Subtype: extreme_value
# Time: 2022-06-19T06:23:09.128Z
# Details:
# {'is_contract': False,
#  'to': '0x786e18f5cf6491bd06485b29e4363369a2fc3a51',
#  'value': 924000.0,
#  'z_score': 4.565635532730704}
#
# Subtype: extreme_value
# Time: 2022-06-22T17:08:30.201Z
# Details:
# {'is_contract': False,
#  'to': '0x20fa6911df9318f257f7ae0f3f8398cbfd658ccf',
#  'value': 700000.0,
#  'z_score': 3.3557790416386095}
#
# Subtype: extreme_value
# Time: 2022-06-29T04:01:25.457Z
# Details:
# {'is_contract': False,
#  'to': '0x2ed922ea265e7603b63a718163b49d4be468f5eb',
#  'value': 759284.05,
#  'z_score': 3.6759807948115037}
#
# Subtype: extreme_value
# Time: 2022-07-07T01:16:23.115Z
# Details:
# {'is_contract': False,
#  'to': '0x85cbe295da63315d7c65969c959a9f6e99434535',
#  'value': 806900.5,
#  'z_score': 3.9331641480046384}
#
# Subtype: extreme_value
# Time: 2022-07-25T06:26:19.299Z
# Details:
# {'is_contract': False,
#  'to': '0xd390a73f6e9725dd4c29a3af146e2ee169123943',
#  'value': 910000.0,
#  'z_score': 4.490019502037449}
#
# Subtype: extreme_value
# Time: 2022-08-03T00:05:21.157Z
# Details:
# {'is_contract': False,
#  'to': '0x69c8e6a21d0f3374a13bc1186762458da4a6e784',
#  'value': 680330.0,
#  'z_score': 3.249538518514585}
#
# Subtype: extreme_value
# Time: 2022-08-06T05:54:45.649Z
# Details:
# {'is_contract': False,
#  'to': '0x9f110e58be892fb25513658758b41b8b6633f6e0',
#  'value': 736410.766,
#  'z_score': 3.5524388701686775}
#
# Subtype: extreme_value
# Time: 2022-08-20T05:09:31.827Z
# Details:
# {'is_contract': False,
#  'to': '0x9324e8c5a74e46b56559660e2ce9b210cf0a5203',
#  'value': 995972.25,
#  'z_score': 4.9543680945208965}
#
# Subtype: extreme_value
# Time: 2022-08-29T13:54:45.293Z
# Details:
# {'is_contract': False,
#  'to': '0x1bf621aa9cee3f6154881c25041bb39aed4ca7cc',
#  'value': 995726.228,
#  'z_score': 4.953039294013524}
#
# Subtype: extreme_value
# Time: 2022-09-03T19:02:14.703Z
# Details:
# {'is_contract': False,
#  'to': '0xe2e406c83e1d61030dcc479c7bee5488b8cf7b21',
#  'value': 783300.0,
#  'z_score': 3.8056944242634825}
#
# Subtype: extreme_value
# Time: 2022-09-07T12:49:26.935Z
# Details:
# {'is_contract': False,
#  'to': '0x9eca8fe7fa7493f34d6f7a0e214da8ec5c99e1d0',
#  'value': 981750.0,
#  'z_score': 4.877551659340385}
#
# Subtype: extreme_value
# Time: 2022-09-17T12:02:49.837Z
# Details:
# {'is_contract': False,
#  'to': '0xc01d5a1bb3d9d14d933098d5fe4df9f73eb1f001',
#  'value': 699994.75,
#  'z_score': 3.3557506856270995}
#
# Subtype: extreme_value
# Time: 2022-10-11T16:33:49.743Z
# Details:
# {'is_contract': False,
#  'to': '0xf982f8cf501ec3e47d56b137ea1d1432f7a7071e',
#  'value': 675500.0,
#  'z_score': 3.2234509879254114}
#
# Subtype: extreme_value
# Time: 2022-11-15T14:47:58.183Z
# Details:
# {'is_contract': False,
#  'to': '0xe6af06584d5df7a344573cf49207feb5aba8aed9',
#  'value': 700000.0,
#  'z_score': 3.3557790416386095}
#
# Subtype: extreme_value
# Time: 2022-11-16T20:36:50.779Z
# Details:
# {'is_contract': False,
#  'to': '0x7c5afd02591823238347fec53421d9e3f27c87b6',
#  'value': 936061.392,
#  'z_score': 4.630780860421804}
#
# Subtype: extreme_value
# Time: 2022-11-20T00:25:38.078Z
# Details:
# {'is_contract': False,
#  'to': '0x9037d84868307ff7269c797c021693c28cd3645b',
#  'value': 679000.0,
#  'z_score': 3.2423549955987254}
#
# Subtype: extreme_value
# Time: 2022-11-26T11:25:50.188Z
# Details:
# {'is_contract': False,
#  'to': '0x8fa7041644e31eb19207d13c5cf152336f68f4ff',
#  'value': 731568.698,
#  'z_score': 3.5262861585610468}
#
# Subtype: extreme_value
# Time: 2022-11-30T21:33:10.197Z
# Details:
# {'is_contract': False,
#  'to': '0x89aff11e30557d599ebc849368e978e693e0c2a0',
#  'value': 749000.0,
#  'z_score': 3.6204351490650053}
#
# Subtype: extreme_value
# Time: 2022-12-05T22:17:36.329Z
# Details:
# {'is_contract': False,
#  'to': '0x29f5efb2070989b5055051764701971694eb5608',
#  'value': 821799.146,
#  'z_score': 4.013633896092063}
#
# Subtype: extreme_value
# Time: 2022-12-14T08:24:20.709Z
# Details:
# {'is_contract': False,
#  'to': '0x13678b9095c9702d753209a89bdaae8ea273973b',
#  'value': 980588.7945,
#  'z_score': 4.871279820002587}
#
# Subtype: extreme_value
# Time: 2023-01-18T10:32:10.980Z
# Details:
# {'is_contract': False,
#  'to': '0xc84c61693b0e8979396a2a87de6ff2f40ab5ec0c',
#  'value': 943071.64,
#  'z_score': 4.6686442267029}
#
# Subtype: extreme_value
# Time: 2023-01-19T21:19:34.140Z
# Details:
# {'is_contract': False,
#  'to': '0xdc26c9d0e45f4519f616c217180ab0499a36b6d9',
#  'value': 651000.0,
#  'z_score': 3.0911229342122133}
#
# Subtype: extreme_value
# Time: 2023-01-29T17:25:57.713Z
# Details:
# {'is_contract': False,
#  'to': '0x902e60795d5ac1755570a5be1d8007a18bfd76d8',
#  'value': 817466.02,
#  'z_score': 3.990230054048225}
#
# Subtype: extreme_value
# Time: 2023-02-03T22:34:57.875Z
# Details:
# {'is_contract': False,
#  'to': '0x23463311407dc6356c46a3df3575759220712c2c',
#  'value': 864538.5,
#  'z_score': 4.244475346368773}
#
# Subtype: extreme_value
# Time: 2023-02-09T13:14:14.138Z
# Details:
# {'is_contract': False,
#  'to': '0xdfd532ed7c2781eb7247db2a136ca43f77819e24',
#  'value': 738208.1,
#  'z_score': 3.5621465318051087}
#
# Subtype: extreme_value
# Time: 2023-02-15T01:52:37.281Z
# Details:
# {'is_contract': False,
#  'to': '0x1bf621aa9cee3f6154881c25041bb39aed4ca7cc',
#  'value': 708358.413,
#  'z_score': 3.4009240426353884}
#
# Subtype: extreme_value
# Time: 2023-02-27T06:02:14.082Z
# Details:
# {'is_contract': False,
#  'to': '0x2b4d249ce6de06bd367290220c4ba1c8355087da',
#  'value': 859069.2285,
#  'z_score': 4.214935017682077}
#
# Subtype: extreme_value
# Time: 2023-03-14T23:58:07.695Z
# Details:
# {'is_contract': False,
#  'to': '0x289f519a967fdefeef7622b14d002ddb6ee0027e',
#  'value': 692898.9165,
#  'z_score': 3.317425059646369}
#
# Subtype: extreme_value
# Time: 2023-03-20T23:35:58.748Z
# Details:
# {'is_contract': False,
#  'to': '0x7ab27f5b7dd06fbd928783b2d809f4d79c05f654',
#  'value': 756770.0,
#  'z_score': 3.6624020460997624}
#
# Subtype: extreme_value
# Time: 2023-03-22T23:44:25.458Z
# Details:
# {'is_contract': False,
#  'to': '0x6169c02698b5120bd36e002a85948bdfbf3aaf5b',
#  'value': 737904.65,
#  'z_score': 3.5605075543398326}
#
# Subtype: extreme_value
# Time: 2023-03-26T01:59:24.262Z
# Details:
# {'is_contract': False,
#  'to': '0xb79550fbecd2d0d0828f26a5bdda9f07640a2a2f',
#  'value': 679000.0,
#  'z_score': 3.2423549955987254}
#
# Subtype: extreme_value
# Time: 2023-04-07T03:54:45.759Z
# Details:
# {'is_contract': False,
#  'to': '0x8f027645ad7deb3c12da320d178ac5d9bd2da15b',
#  'value': 854000.0,
#  'z_score': 4.187555379264425}
#
# Subtype: extreme_value
# Time: 2023-05-20T15:15:33.013Z
# Details:
# {'is_contract': False,
#  'to': '0xdffad44a1b0ef685b30cd218183506239476b3e7',
#  'value': 867733.3,
#  'z_score': 4.261730924572975}
#
# Subtype: extreme_value
# Time: 2023-05-24T16:24:35.629Z
# Details:
# {'is_contract': False,
#  'to': '0xc3cfaed10ab8f0cf703eb4bf1a1578aa7a3e636d',
#  'value': 847000.0,
#  'z_score': 4.149747363917797}
#
# Subtype: extreme_value
# Time: 2023-05-25T00:41:22.519Z
# Details:
# {'is_contract': False,
#  'to': '0xd80bb4401022eb615c8a3f9be0c160d8de195076',
#  'value': 962500.0,
#  'z_score': 4.773579617137159}
#
# Subtype: extreme_value
# Time: 2023-05-27T04:39:29.865Z
# Details:
# {'is_contract': False,
#  'to': '0x5e90e3c1df7b1c9601990bb18e3acb077dce8006',
#  'value': 854000.0,
#  'z_score': 4.187555379264425}
#
# Subtype: extreme_value
# Time: 2023-05-29T12:12:39.467Z
# Details:
# {'is_contract': False,
#  'to': '0x09ca231039b2112d6436f28e99518f4b6d8385fb',
#  'value': 850500.0,
#  'z_score': 4.168651371591111}
#
# Subtype: extreme_value
# Time: 2023-06-07T12:58:29.131Z
# Details:
# {'is_contract': False,
#  'to': '0x1ffeb61271aad3e592e6f83dd4c01cacaa678820',
#  'value': 686000.0,
#  'z_score': 3.2801630109453535}
#
# Subtype: extreme_value
# Time: 2023-06-21T13:20:19.395Z
# Details:
# {'is_contract': False,
#  'to': '0x7839b8ed7b3b9637570188a35eea64f6d4bf8988',
#  'value': 899220.0,
#  'z_score': 4.4317951584036415}
#
# Subtype: extreme_value
# Time: 2023-06-29T00:13:48.155Z
# Details:
# {'is_contract': False,
#  'to': '0x0cbc4b454da6c1af2b1369145b49ac44ac0c2ce0',
#  'value': 679000.0,
#  'z_score': 3.2423549955987254}
#
# Subtype: extreme_value
# Time: 2023-07-08T01:06:25.063Z
# Details:
# {'is_contract': False,
#  'to': '0x6ca7ec5d3b254a26f5ee1eb4f18197dd4e71cc25',
#  'value': 888801.4975,
#  'z_score': 4.375523315202373}
#
# Subtype: extreme_value
# Time: 2023-07-08T13:35:18.710Z
# Details:
# {'is_contract': False,
#  'to': '0x1bf621aa9cee3f6154881c25041bb39aed4ca7cc',
#  'value': 947481.472,
#  'z_score': 4.692462368978907}
#
# Subtype: extreme_value
# Time: 2023-07-11T05:52:27.413Z
# Details:
# {'is_contract': False,
#  'to': '0x021d5dea34858d29631afe3e7dd462c59fa8d280',
#  'value': 733292.3605,
#  'z_score': 3.5355959097399623}
#
# Subtype: extreme_value
# Time: 2023-07-26T14:25:16.886Z
# Details:
# {'is_contract': False,
#  'to': '0x5d913437e257ab194d6c0e51348ac5e0508ec65e',
#  'value': 782792.5,
#  'z_score': 3.8029533431508518}
#
# Subtype: extreme_value
# Time: 2023-07-29T16:48:04.436Z
# Details:
# {'is_contract': False,
#  'to': '0xc8ac41274dce8beb77c8ed7ff23f75914d5aae9d',
#  'value': 876901.2,
#  'z_score': 4.311248082272453}
#
# Subtype: extreme_value
# Time: 2023-08-18T23:56:53.652Z
# Details:
# {'is_contract': False,
#  'to': '0x5532bd2caa833efdb7636b990b3d4d453b949be5',
#  'value': 927815.0,
#  'z_score': 4.586240901094617}
#
# Subtype: extreme_value
# Time: 2023-09-14T19:26:23.756Z
# Details:
# {'is_contract': False,
#  'to': '0xba47a124584b0312e0c3c7aab76cdbe7dc2fb5d7',
#  'value': 934500.0,
#  'z_score': 4.622347555750647}
#
# Subtype: extreme_value
# Time: 2023-10-11T22:15:22.864Z
# Details:
# {'is_contract': False,
#  'to': '0xea16689777bd8efe15cedfc528acf93dbec7e7fc',
#  'value': 682429.65,
#  'z_score': 3.260879032717806}
#
# Subtype: extreme_value
# Time: 2023-10-30T19:38:36.785Z
# Details:
# {'is_contract': False,
#  'to': '0x09a99a2c52e814e6c07a1e1cb9e7d902f30f1bf2',
#  'value': 770000.0,
#  'z_score': 3.733859195104889}
#
# Subtype: extreme_value
# Time: 2023-11-07T05:05:05.688Z
# Details:
# {'is_contract': False,
#  'to': '0x1bf621aa9cee3f6154881c25041bb39aed4ca7cc',
#  'value': 640085.4775,
#  'z_score': 3.0321720150434825}
#
# Subtype: extreme_value
# Time: 2023-11-17T00:33:44.752Z
# Details:
# {'is_contract': False,
#  'to': '0x128f53455ca4b0036eae439c7f71d748501377b8',
#  'value': 886721.2585,
#  'z_score': 4.364287642625708}
#
# Subtype: extreme_value
# Time: 2023-11-22T04:22:03.998Z
# Details:
# {'is_contract': False,
#  'to': '0xba824e48600f165bd745ea0bbe3b1d7856811d28',
#  'value': 675500.0,
#  'z_score': 3.2234509879254114}
#
# Subtype: extreme_value
# Time: 2023-12-09T23:54:57.450Z
# Details:
# {'is_contract': False,
#  'to': '0x6dae6317ea8c8cab9b10f1d4b5d7ccccb56f2424',
#  'value': 996662.6075,
#  'z_score': 4.95809681551442}
#
# Subtype: extreme_value
# Time: 2023-12-23T22:01:35.378Z
# Details:
# {'is_contract': False,
#  'to': '0x480629af30f853df7370b4834004cd9788181e01',
#  'value': 928208.68,
#  'z_score': 4.588367223877712}
#
# Subtype: extreme_value
# Time: 2023-12-26T10:31:55.632Z
# Details:
# {'is_contract': False,
#  'to': '0x8f5950e0a76a8250b5a04372f0b06382919819a4',
#  'value': 934386.3375,
#  'z_score': 4.621733648101456}
#
# Subtype: extreme_value
# Time: 2024-01-03T15:40:21.411Z
# Details:
# {'is_contract': False,
#  'to': '0x106c6371cb99fe400943e7fe7fe1725fcfe33299',
#  'value': 854000.0,
#  'z_score': 4.187555379264425}
#
# Subtype: extreme_value
# Time: 2024-01-05T07:53:02.057Z
# Details:
# {'is_contract': False,
#  'to': '0x8e2125e792aa4553b64a8d0667ef4dd6f3320e01',
#  'value': 854000.0,
#  'z_score': 4.187555379264425}
#
# Subtype: extreme_value
# Time: 2024-01-06T21:41:56.460Z
# Details:
# {'is_contract': False,
#  'to': '0x17340baf69adbee27761d158ee698b57c9eb2eda',
#  'value': 711088.3395,
#  'z_score': 3.4156687716364122}
#
# Subtype: extreme_value
# Time: 2024-01-09T01:30:29.980Z
# Details:
# {'is_contract': False,
#  'to': '0xe3f02c606cc1163f28cdff24b6750979cdb1a61d',
#  'value': 854000.0,
#  'z_score': 4.187555379264425}
#
# Subtype: extreme_value
# Time: 2024-01-16T17:02:11.959Z
# Details:
# {'is_contract': False,
#  'to': '0xacfc6fa3cd35f417372503e0d0d0a92a2df11ac1',
#  'value': 689188.5,
#  'z_score': 3.2973845619357425}
#
# Subtype: extreme_value
# Time: 2024-01-18T11:54:03.394Z
# Details:
# {'is_contract': False,
#  'to': '0x234952d688ec518b8562f5e2fe77bc2826607e11',
#  'value': 998468.079,
#  'z_score': 4.967848428968691}
#
# Subtype: extreme_value
# Time: 2024-02-06T03:08:08.599Z
# Details:
# {'is_contract': False,
#  'to': '0xd926444ab8903b5cc418e1456e00a46229beabdf',
#  'value': 801500.0,
#  'z_score': 3.903995264164715}
#
# Subtype: extreme_value
# Time: 2024-02-19T07:51:15.580Z
# Details:
# {'is_contract': False,
#  'to': '0x8458751da3cfebe6ed813c349ac598596890fdaf',
#  'value': 636384.728,
#  'z_score': 3.01218373020205}
#
# Subtype: extreme_value
# Time: 2024-02-19T20:41:33.521Z
# Details:
# {'is_contract': False,
#  'to': '0xe4687a51560309c6f66f097a0438ea5624a04395',
#  'value': 850500.0,
#  'z_score': 4.168651371591111}
#
# Subtype: extreme_value
# Time: 2024-02-25T01:04:30.282Z
# Details:
# {'is_contract': False,
#  'to': '0xb9cb348907ef5a9ddf2e22c3705f4ba5a899c754',
#  'value': 696500.0,
#  'z_score': 3.3368750339652955}
#
# Subtype: extreme_value
# Time: 2024-02-26T14:07:31.847Z
# Details:
# {'is_contract': False,
#  'to': '0xfb81eed19a812ccd9efa3ff1a96aff0167efaf9f',
#  'value': 976920.0,
#  'z_score': 4.851464128751212}
#
# Subtype: extreme_value
# Time: 2024-03-08T12:27:31.582Z
# Details:
# {'is_contract': False,
#  'to': '0x766ec1eb276e939a56350fee894e35b1c3cb1779',
#  'value': 841554.231,
#  'z_score': 4.120333975642627}
#
# Subtype: extreme_value
# Time: 2024-03-11T08:08:39.971Z
# Details:
# {'is_contract': False,
#  'to': '0x0177c959825a151ef3bb2744e5088ca9f1f6da37',
#  'value': 749000.0,
#  'z_score': 3.6204351490650053}
#
# Subtype: extreme_value
# Time: 2024-03-16T21:04:51.674Z
# Details:
# {'is_contract': False,
#  'to': '0x46df24f34033b4aed64fd69900874e16806d1b5a',
#  'value': 679000.0,
#  'z_score': 3.2423549955987254}
#
# Subtype: extreme_value
# Time: 2024-03-19T05:31:17.610Z
# Details:
# {'is_contract': False,
#  'to': '0x95b7e2712a229bd518005f04aec5da9a8fb306bf',
#  'value': 871500.0,
#  'z_score': 4.2820754176309945}
#
# Subtype: extreme_value
# Time: 2024-04-03T22:27:51.413Z
# Details:
# {'is_contract': False,
#  'to': '0xafae9a7d3445b2269e073e99cdcdc849ece3c915',
#  'value': 734580.0,
#  'z_score': 3.5425506374509514}
#
# Subtype: extreme_value
# Time: 2024-04-06T00:23:16.099Z
# Details:
# {'is_contract': False,
#  'to': '0x7794aaf0891e076db24f345f75f1922d2f552373',
#  'value': 807505.594,
#  'z_score': 3.936432348467232}
#
# Subtype: extreme_value
# Time: 2024-04-09T18:34:59.520Z
# Details:
# {'is_contract': False,
#  'to': '0x257d2992ff574a1cffa6993d33a5225f161edcd6',
#  'value': 716392.25,
#  'z_score': 3.4443159615765753}
#
# Subtype: extreme_value
# Time: 2024-05-04T09:13:32.980Z
# Details:
# {'is_contract': False,
#  'to': '0x495602bc37ca2f5f368e3925f28234760459a2e8',
#  'value': 994000.0,
#  'z_score': 4.943715686196985}
#
# Subtype: extreme_value
# Time: 2024-05-21T04:08:25.249Z
# Details:
# {'is_contract': False,
#  'to': '0xf97401114ccebba7445571bd78e19457b1264d97',
#  'value': 679000.0,
#  'z_score': 3.2423549955987254}
#
# Subtype: extreme_value
# Time: 2024-05-25T03:19:59.045Z
# Details:
# {'is_contract': False,
#  'to': '0xdcd8bf4971a2c250e14d4cfb6b8596dbb6f59f52',
#  'value': 927500.0,
#  'z_score': 4.584539540404019}
#
# Subtype: extreme_value
# Time: 2024-05-30T08:55:12.613Z
# Details:
# {'is_contract': False,
#  'to': '0xc1fa69240dd804e398b85a5602f5a96de98dec13',
#  'value': 864973.8615,
#  'z_score': 4.246826796979249}
#
# Subtype: extreme_value
# Time: 2024-06-10T20:44:18.570Z
# Details:
# {'is_contract': False,
#  'to': '0xc82d4a18667920a5b59320741d6ef66f0b2c115b',
#  'value': 857500.0,
#  'z_score': 4.2064593869377385}
#
# Subtype: extreme_value
# Time: 2024-07-05T23:24:23.290Z
# Details:
# {'is_contract': False,
#  'to': '0xc9e64a51386db2795f4336c74b7dc342287ec9e2',
#  'value': 873285.0,
#  'z_score': 4.291716461544385}
#
# Subtype: extreme_value
# Time: 2024-07-15T23:16:57.500Z
# Details:
# {'is_contract': False,
#  'to': '0xeb895c2948f3fe0a3f0f84cbd1c16ba63157cbd5',
#  'value': 700000.0,
#  'z_score': 3.3557790416386095}
#
# Subtype: extreme_value
# Time: 2024-07-16T09:19:55.644Z
# Details:
# {'is_contract': False,
#  'to': '0x38ae10abca8135462dca584dd109b6f55cf10bf2',
#  'value': 769994.883,
#  'z_score': 3.733831557445671}
#
# Subtype: extreme_value
# Time: 2024-08-06T11:08:01.382Z
# Details:
# {'is_contract': False,
#  'to': '0x55bdd424dbddf5f5d9d7fb978e1f6bd4d03b1e84',
#  'value': 703500.0,
#  'z_score': 3.374683049311923}
#
# Subtype: extreme_value
# Time: 2024-08-20T14:46:52.948Z
# Details:
# {'is_contract': False,
#  'to': '0xf2b4f20fe6a5dd82058cc7307aeafd1b92f1e803',
#  'value': 854000.0,
#  'z_score': 4.187555379264425}
#
# Subtype: extreme_value
# Time: 2024-08-28T07:19:26.165Z
# Details:
# {'is_contract': False,
#  'to': '0x77f7b398a23ef4cab31dd5503fd8446c4480c70b',
#  'value': 773500.0,
#  'z_score': 3.752763202778203}
#
# Subtype: extreme_value
# Time: 2024-09-11T02:41:33.365Z
# Details:
# {'is_contract': False,
#  'to': '0x1b839a222c93833a3e9b8ed7068362ab25c80f56',
#  'value': 822500.0,
#  'z_score': 4.017419310204599}
#
# Subtype: extreme_value
# Time: 2024-09-27T06:28:54.752Z
# Details:
# {'is_contract': False,
#  'to': '0xecc64e3f8126d270d6b4727614c77b18155f3253',
#  'value': 956130.0,
#  'z_score': 4.739174323171727}
#
# Subtype: extreme_value
# Time: 2024-09-27T21:19:05.091Z
# Details:
# {'is_contract': False,
#  'to': '0x7329f38498cc145d27d287893a3bb48001f7a0b0',
#  'value': 679000.0,
#  'z_score': 3.2423549955987254}
#
# Subtype: extreme_value
# Time: 2024-09-28T10:20:23.825Z
# Details:
# {'is_contract': False,
#  'to': '0xe2e6e586e2b73569bc0b145c054f7691cb699f2e',
#  'value': 876750.0,
#  'z_score': 4.310431429140966}
#
# Subtype: extreme_value
# Time: 2024-09-30T01:33:44.581Z
# Details:
# {'is_contract': False,
#  'to': '0x9ca27bed69b390b3cc99b06a63d342e671d75c1d',
#  'value': 696500.0,
#  'z_score': 3.3368750339652955}
#
# Subtype: extreme_value
# Time: 2024-10-04T19:30:44.031Z
# Details:
# {'is_contract': False,
#  'to': '0x41900cb1e7b07f94aba1f14e50ddfc2ac914c1ba',
#  'value': 646181.5675,
#  'z_score': 3.0650978813684007}
#
# Subtype: extreme_value
# Time: 2024-10-17T22:52:21.732Z
# Details:
# {'is_contract': False,
#  'to': '0x1647382abceb91aee30fd70bf48a7b1567c0eeb4',
#  'value': 675500.0,
#  'z_score': 3.2234509879254114}
#
# Subtype: extreme_value
# Time: 2024-11-07T04:53:02.521Z
# Details:
# {'is_contract': False,
#  'to': '0x5e202c8bcb5a50fd6523da18c6e80f83616d3516',
#  'value': 731972.3495,
#  'z_score': 3.528466338862003}
#
# Subtype: extreme_value
# Time: 2024-11-14T07:15:15.114Z
# Details:
# {'is_contract': False,
#  'to': '0xe75022a649ff5fba753550dc5adf80538c9d90f1',
#  'value': 906500.0,
#  'z_score': 4.471115494364135}
#
# TEMPORAL ANOMALIES:
#
# Subtype: unusual_timing
# Time: 2021-06-09T06:59:54.285Z
# Details:
# {'time_diff': 40.03145,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.75085351496493}
#
# Subtype: unusual_timing
# Time: 2021-06-22T07:02:18.913Z
# Details:
# {'time_diff': 53.02976861111111,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 5.294146400129325}
#
# Subtype: unusual_timing
# Time: 2021-07-17T08:12:06.745Z
# Details:
# {'time_diff': 39.78044472222222,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.721051609739894}
#
# Subtype: unusual_timing
# Time: 2021-09-08T14:12:51.135Z
# Details:
# {'time_diff': 46.86397305555556,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.562080300123663}
#
# Subtype: unusual_timing
# Time: 2021-09-28T14:23:51.646Z
# Details:
# {'time_diff': 33.72273583333333,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.0018186605930817}
#
# Subtype: unusual_timing
# Time: 2021-11-11T19:58:06.940Z
# Details:
# {'time_diff': 55.23063722222222,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 5.555455956413472}
#
# Subtype: unusual_timing
# Time: 2021-11-18T19:23:19.520Z
# Details:
# {'time_diff': 39.37120527777778,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.6724625312724792}
#
# Subtype: unusual_timing
# Time: 2021-12-08T19:38:18.793Z
# Details:
# {'time_diff': 45.02238444444445,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.343428127795921}
#
# Subtype: unusual_timing
# Time: 2021-12-26T09:24:16.907Z
# Details:
# {'time_diff': 36.98089888888889,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.388660990957728}
#
# Subtype: unusual_timing
# Time: 2022-01-21T01:48:10.279Z
# Details:
# {'time_diff': 35.206705,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.1780106070470113}
#
# Subtype: unusual_timing
# Time: 2022-02-18T13:32:42.514Z
# Details:
# {'time_diff': 49.56691083333333,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.883000625766451}
#
# Subtype: unusual_timing
# Time: 2022-03-07T22:40:15.041Z
# Details:
# {'time_diff': 41.41480472222222,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.9150994889510704}
#
# Subtype: unusual_timing
# Time: 2022-04-08T20:00:41.138Z
# Details:
# {'time_diff': 42.58256444444444,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.053747826848141}
#
# Subtype: unusual_timing
# Time: 2022-04-19T05:09:14.037Z
# Details:
# {'time_diff': 35.36389527777778,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.1966738391595166}
#
# Subtype: unusual_timing
# Time: 2022-05-29T17:42:36.785Z
# Details:
# {'time_diff': 35.517445555555554,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.214904893367319}
#
# Subtype: unusual_timing
# Time: 2022-06-22T02:30:29.494Z
# Details:
# {'time_diff': 61.35043138888889,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 6.282060302610515}
#
# Subtype: unusual_timing
# Time: 2022-07-20T14:24:27.817Z
# Details:
# {'time_diff': 40.99456694444444,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.8652045762377174}
#
# Subtype: unusual_timing
# Time: 2022-11-15T14:47:58.183Z
# Details:
# {'time_diff': 45.48544833333333,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.398407792972606}
#
# Subtype: unusual_timing
# Time: 2022-11-19T11:02:00.528Z
# Details:
# {'time_diff': 45.94785388888889,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.453309294105174}
#
# Subtype: unusual_timing
# Time: 2022-11-25T12:37:00.647Z
# Details:
# {'time_diff': 46.394799166666665,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.506375193464083}
#
# Subtype: unusual_timing
# Time: 2022-12-08T11:30:08.563Z
# Details:
# {'time_diff': 59.357056944444444,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 6.045386568905454}
#
# Subtype: unusual_timing
# Time: 2023-01-14T17:23:18.270Z
# Details:
# {'time_diff': 36.93354333333333,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.3830384566786083}
#
# Subtype: unusual_timing
# Time: 2023-02-27T06:02:14.082Z
# Details:
# {'time_diff': 62.50538833333333,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 6.419188564223417}
#
# Subtype: unusual_timing
# Time: 2023-03-14T20:31:11.385Z
# Details:
# {'time_diff': 57.83419305555556,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 5.864576644552084}
#
# Subtype: unusual_timing
# Time: 2023-05-14T08:59:24.677Z
# Details:
# {'time_diff': 42.98392138888889,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.101401014564508}
#
# Subtype: unusual_timing
# Time: 2023-06-09T14:05:25.894Z
# Details:
# {'time_diff': 35.53042166666667,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.2164455495517097}
#
# Subtype: unusual_timing
# Time: 2023-06-15T18:50:12.122Z
# Details:
# {'time_diff': 36.85684333333333,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.373931850829531}
#
# Subtype: unusual_timing
# Time: 2023-06-17T13:06:25.173Z
# Details:
# {'time_diff': 42.270291944444445,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.01667165246736}
#
# Subtype: unusual_timing
# Time: 2023-07-05T17:10:49.904Z
# Details:
# {'time_diff': 57.1875075,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 5.787795543343013}
#
# Subtype: unusual_timing
# Time: 2023-07-11T05:52:27.413Z
# Details:
# {'time_diff': 43.764968333333336,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.1941348694886464}
#
# Subtype: unusual_timing
# Time: 2023-07-19T14:11:39.713Z
# Details:
# {'time_diff': 44.91165861111111,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.3302816281677945}
#
# Subtype: unusual_timing
# Time: 2023-07-26T02:32:28.323Z
# Details:
# {'time_diff': 40.64861527777778,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.8241296678783363}
#
# Subtype: unusual_timing
# Time: 2023-07-31T08:26:34.649Z
# Details:
# {'time_diff': 37.86664916666667,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.4938262929190396}
#
# Subtype: unusual_timing
# Time: 2023-09-14T19:26:23.756Z
# Details:
# {'time_diff': 34.58817833333333,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.104572816167263}
#
# Subtype: unusual_timing
# Time: 2023-10-08T13:41:38.687Z
# Details:
# {'time_diff': 51.103120555555556,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 5.065395103495233}
#
# Subtype: unusual_timing
# Time: 2023-10-11T11:36:00.177Z
# Details:
# {'time_diff': 38.937691388888894,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.6209913433166565}
#
# Subtype: unusual_timing
# Time: 2023-10-13T15:42:53.835Z
# Details:
# {'time_diff': 41.45860305555555,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.920299673547069}
#
# Subtype: unusual_timing
# Time: 2023-10-27T04:01:22.201Z
# Details:
# {'time_diff': 37.51328972222222,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.4518718576699605}
#
# Subtype: unusual_timing
# Time: 2023-12-02T03:38:51.321Z
# Details:
# {'time_diff': 55.220350277777776,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 5.554234585508037}
#
# Subtype: unusual_timing
# Time: 2023-12-12T08:56:43.048Z
# Details:
# {'time_diff': 42.10465972222222,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.997006106656611}
#
# Subtype: unusual_timing
# Time: 2023-12-19T15:42:05.004Z
# Details:
# {'time_diff': 55.883355,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 5.632953264534823}
#
# Subtype: unusual_timing
# Time: 2024-01-10T21:09:10.963Z
# Details:
# {'time_diff': 43.6447175,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.179857464766486}
#
# Subtype: unusual_timing
# Time: 2024-01-20T00:37:34.565Z
# Details:
# {'time_diff': 36.72532527777778,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.3583166866315985}
#
# Subtype: unusual_timing
# Time: 2024-02-01T12:08:12.246Z
# Details:
# {'time_diff': 52.5673175,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 5.2392394901768276}
#
# Subtype: unusual_timing
# Time: 2024-02-14T04:41:11.780Z
# Details:
# {'time_diff': 46.7861725,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.552843025100407}
#
# Subtype: unusual_timing
# Time: 2024-03-26T08:07:12.078Z
# Details:
# {'time_diff': 35.070389444444444,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.1618258347452857}
#
# Subtype: unusual_timing
# Time: 2024-04-20T12:22:38.369Z
# Details:
# {'time_diff': 49.563497222222225,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.882595327058356}
#
# Subtype: unusual_timing
# Time: 2024-04-22T19:07:43.926Z
# Details:
# {'time_diff': 36.288558611111114,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.306459295740485}
#
# Subtype: unusual_timing
# Time: 2024-04-28T13:32:02.967Z
# Details:
# {'time_diff': 36.146408055555554,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.2895817327591055}
#
# Subtype: unusual_timing
# Time: 2024-05-09T00:05:44.166Z
# Details:
# {'time_diff': 43.47445583333333,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.159642264120589}
#
# Subtype: unusual_timing
# Time: 2024-06-10T03:33:35.040Z
# Details:
# {'time_diff': 36.28179472222222,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.3056562179032216}
#
# Subtype: unusual_timing
# Time: 2024-06-17T10:32:53.549Z
# Details:
# {'time_diff': 37.691741388888886,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.473059458601436}
#
# Subtype: unusual_timing
# Time: 2024-08-09T09:16:06.693Z
# Details:
# {'time_diff': 44.291484999999994,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.256648295255309}
#
# Subtype: unusual_timing
# Time: 2024-08-25T03:35:13.698Z
# Details:
# {'time_diff': 36.62468972222222,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.3463682076375005}
#
# Subtype: unusual_timing
# Time: 2024-09-24T19:18:31.776Z
# Details:
# {'time_diff': 47.411185833333334,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 4.6270509791693035}
#
# Subtype: unusual_timing
# Time: 2024-10-10T08:29:00.295Z
# Details:
# {'time_diff': 41.57960805555556,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.9346666206235703}
#
# Subtype: unusual_timing
# Time: 2024-11-08T18:35:20.949Z
# Details:
# {'time_diff': 35.818873611111115,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 3.250693504759733}
#
# Subtype: unusual_timing
# Time: 2024-11-22T23:48:22.452Z
# Details:
# {'time_diff': 72.16200777777777,
#  'usual_time_diff': 8.440045983434011,
#  'z_score': 7.5657208603784}
#
# Contract anomalies by type:
# {'temporal': 58, 'value': 132}
#
# Analyzing wallet...
#
# Analyzing anomalies for address: 0xeba88149813bec1cccccfdb0dacefaaa5de94cb1
# ==================================================
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Anomaly Score: 0.5283
# Is Anomalous: True
#
# Detected Anomalies:
#
# VALUE ANOMALIES:
#
# Subtype: extreme_value
# Time: 2024-08-29T15:16:52.541Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 19318.614,
#  'z_score': 4.315940532309118}
#
# Subtype: extreme_value
# Time: 2024-09-07T07:27:42.491Z
# Details:
# {'is_contract': False,
#  'to': '0xf1999b090747cc2d4c9ea287ada9321d092044f0',
#  'value': 42890.61742,
#  'z_score': 9.894156983729106}
#
# Subtype: extreme_value
# Time: 2024-09-07T08:00:22.155Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 20998.845,
#  'z_score': 4.713560201684928}
#
# Subtype: extreme_value
# Time: 2024-09-08T12:28:39.632Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 27999.384,
#  'z_score': 6.370208604572662}
#
# Subtype: extreme_value
# Time: 2024-09-09T05:25:25.513Z
# Details:
# {'is_contract': False,
#  'to': '0xa3f27ae63b409f1e06be5665eba1f4002a71f54e',
#  'value': 47426.739255,
#  'z_score': 10.967611326781395}
#
# Subtype: extreme_value
# Time: 2024-09-10T01:06:44.695Z
# Details:
# {'is_contract': False,
#  'to': '0xe30b7177916cb0865426065372afe4cdac34249d',
#  'value': 30804.804065,
#  'z_score': 7.034099580697709}
#
# Subtype: extreme_value
# Time: 2024-09-11T22:10:10.398Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 21163.575965,
#  'z_score': 4.752543098583781}
#
# Subtype: extreme_value
# Time: 2024-09-12T02:43:45.875Z
# Details:
# {'is_contract': False,
#  'to': '0x870bb7bd6e077fffe5d7344c7797fc15cdc52e4c',
#  'value': 14280.0,
#  'z_score': 3.1235735108743707}
#
# Subtype: extreme_value
# Time: 2024-09-15T13:06:55.326Z
# Details:
# {'is_contract': False,
#  'to': '0x612915b5f8ffd9185cdcc6fc1a5012be8f15b266',
#  'value': 19249.40878,
#  'z_score': 4.299563405178694}
#
# Subtype: extreme_value
# Time: 2024-09-15T19:02:47.144Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 15609.307,
#  'z_score': 3.4381484769587662}
#
# Subtype: extreme_value
# Time: 2024-09-16T14:33:38.596Z
# Details:
# {'is_contract': False,
#  'to': '0x685934c3c4935bcf17d4d0a54102002846d9576b',
#  'value': 23645.15979,
#  'z_score': 5.3397995770232685}
#
# Subtype: extreme_value
# Time: 2024-09-18T13:36:07.907Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 16449.384,
#  'z_score': 3.6369492007819915}
#
# Subtype: extreme_value
# Time: 2024-09-18T22:02:38.423Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 24497.998,
#  'z_score': 5.541620188053096}
#
# Subtype: extreme_value
# Time: 2024-09-18T22:13:18.272Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 17499.384,
#  'z_score': 3.885427328399325}
#
# Subtype: extreme_value
# Time: 2024-09-19T05:28:45.995Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 20298.768,
#  'z_score': 4.547889894877347}
#
# Subtype: extreme_value
# Time: 2024-09-19T17:31:31.206Z
# Details:
# {'is_contract': False,
#  'to': '0x680e76f7c19241c222dcb71a7afd7d091ee189e3',
#  'value': 51932.875015,
#  'z_score': 12.033969590052166}
#
# Subtype: extreme_value
# Time: 2024-09-20T09:50:33.118Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 18708.34245,
#  'z_score': 4.17152231127852}
#
# Subtype: extreme_value
# Time: 2024-09-21T04:16:31.986Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 15693.24001,
#  'z_score': 3.4580108742636106}
#
# Subtype: extreme_value
# Time: 2024-09-22T08:14:34.402Z
# Details:
# {'is_contract': False,
#  'to': '0xdd3d72c53ff982ff59853da71158bf1538b3ceee',
#  'value': 35000.0,
#  'z_score': 8.026875229189756}
#
# Subtype: extreme_value
# Time: 2024-09-24T16:03:15.821Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 14686.707,
#  'z_score': 3.219819028825669}
#
# Subtype: extreme_value
# Time: 2024-09-29T05:56:40.430Z
# Details:
# {'is_contract': False,
#  'to': '0xf1999b090747cc2d4c9ea287ada9321d092044f0',
#  'value': 28515.530715,
#  'z_score': 6.492352575352699}
#
# Subtype: extreme_value
# Time: 2024-09-30T04:41:35.813Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 15049.23,
#  'z_score': 3.3056085871668293}
#
# Subtype: extreme_value
# Time: 2024-10-01T05:47:56.788Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 13998.768,
#  'z_score': 3.0570211291733442}
#
# Subtype: extreme_value
# Time: 2024-10-01T06:30:58.335Z
# Details:
# {'is_contract': False,
#  'to': '0x9d5adc634773b327d96b08ea6b79e2e41a94472a',
#  'value': 17263.894795,
#  'z_score': 3.829699788654093}
#
# Subtype: extreme_value
# Time: 2024-10-03T14:44:41.107Z
# Details:
# {'is_contract': False,
#  'to': '0xfb7ce7b78cc7356664d42c43216ebb6c7e49b627',
#  'value': 16282.517405,
#  'z_score': 3.597460915936773}
#
# Subtype: extreme_value
# Time: 2024-10-04T16:54:46.720Z
# Details:
# {'is_contract': False,
#  'to': '0xf3ef588c1821415288d439ae40872b77c6dcab06',
#  'value': 15079.35527,
#  'z_score': 3.3127376068654644}
#
# Subtype: extreme_value
# Time: 2024-10-07T10:13:52.248Z
# Details:
# {'is_contract': False,
#  'to': '0x68d76fbada698955bb53ca01f2c37b57639c8f5c',
#  'value': 13885.75986,
#  'z_score': 3.030278223427899}
#
# Subtype: extreme_value
# Time: 2024-10-11T06:01:22.417Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 14695.866675,
#  'z_score': 3.2219866277719387}
#
# Subtype: extreme_value
# Time: 2024-10-11T19:55:57.021Z
# Details:
# {'is_contract': False,
#  'to': '0x9ccdaf90631885ec44185634affda2c68a7044af',
#  'value': 35987.66976,
#  'z_score': 8.260603165065051}
#
# Subtype: extreme_value
# Time: 2024-10-12T14:42:03.845Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 52498.614,
#  'z_score': 12.167849365016863}
#
# Subtype: extreme_value
# Time: 2024-10-13T02:11:30.520Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 17499.153,
#  'z_score': 3.8853726632112493}
#
# Subtype: extreme_value
# Time: 2024-10-16T07:18:41.275Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 24464.384,
#  'z_score': 5.533665574927639}
#
# Subtype: extreme_value
# Time: 2024-10-16T18:52:51.305Z
# Details:
# {'is_contract': False,
#  'to': '0xfac315a6ece59725275bd64cc11ba51f1baf4c23',
#  'value': 24500.0,
#  'z_score': 5.542093953016419}
#
# Subtype: extreme_value
# Time: 2024-10-18T20:38:43.073Z
# Details:
# {'is_contract': False,
#  'to': '0xa3f27ae63b409f1e06be5665eba1f4002a71f54e',
#  'value': 47427.775885,
#  'z_score': 10.967856640954187}
#
# Subtype: extreme_value
# Time: 2024-10-19T15:09:56.919Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 34999.307,
#  'z_score': 8.026711233625528}
#
# Subtype: extreme_value
# Time: 2024-10-20T00:27:13.473Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 31499.307,
#  'z_score': 7.1984508082344165}
#
# Subtype: extreme_value
# Time: 2024-10-22T01:35:09.416Z
# Details:
# {'is_contract': False,
#  'to': '0x5a3bc65488ad98d8bb75419dd74af39a5c55e258',
#  'value': 17835.23476,
#  'z_score': 3.9649050122123333}
#
# Subtype: extreme_value
# Time: 2024-10-22T15:05:52.778Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 27999.461,
#  'z_score': 6.370226826302021}
#
# Subtype: extreme_value
# Time: 2024-10-24T10:07:09.743Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 20325.63841,
#  'z_score': 4.5542486655107846}
#
# Subtype: extreme_value
# Time: 2024-10-24T21:55:45.193Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 18774.545615,
#  'z_score': 4.187189014594273}
#
# Subtype: extreme_value
# Time: 2024-10-26T11:59:49.038Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 13999.461,
#  'z_score': 3.0571851247375714}
#
# Subtype: extreme_value
# Time: 2024-10-26T19:43:43.808Z
# Details:
# {'is_contract': False,
#  'to': '0x4ca89089274d8b09964dc42cc731ea38f392bb07',
#  'value': 26797.703135,
#  'z_score': 6.085835831878589}
#
# Subtype: extreme_value
# Time: 2024-10-27T02:04:19.631Z
# Details:
# {'is_contract': False,
#  'to': '0xd18f0015976f5b1593025207ea80c8d3c6c4b83b',
#  'value': 36006.903835,
#  'z_score': 8.265154828819767}
#
# Subtype: extreme_value
# Time: 2024-10-29T17:01:56.562Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 93658.691,
#  'z_score': 21.908210189345706}
#
# Subtype: extreme_value
# Time: 2024-10-30T00:08:22.057Z
# Details:
# {'is_contract': False,
#  'to': '0xe5dc11ff1697dc4489ad30790fc172cebd1d871a',
#  'value': 13775.14061,
#  'z_score': 3.0041006385532003}
#
# Subtype: extreme_value
# Time: 2024-10-30T04:56:00.212Z
# Details:
# {'is_contract': False,
#  'to': '0xdcf207b30deee03432fe6d35eec0219e86e9bf70',
#  'value': 17501.18489,
#  'z_score': 3.885853501518606}
#
# Subtype: extreme_value
# Time: 2024-10-30T06:32:45.520Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 20455.561,
#  'z_score': 4.584994305414018}
#
# Subtype: extreme_value
# Time: 2024-10-30T08:34:48.167Z
# Details:
# {'is_contract': False,
#  'to': '0xe20c08355e9eb3bd894ec66d7439f1ec7ffb00ea',
#  'value': 17471.58539,
#  'z_score': 3.8788489031010736}
#
# Subtype: extreme_value
# Time: 2024-10-30T18:20:03.441Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 73534.075965,
#  'z_score': 17.145803843710997}
#
# Subtype: extreme_value
# Time: 2024-11-01T09:57:27.858Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 17848.383,
#  'z_score': 3.9680164884567755}
#
# Subtype: extreme_value
# Time: 2024-11-01T14:12:11.574Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 21958.075965,
#  'z_score': 4.940558215147564}
#
# Subtype: extreme_value
# Time: 2024-11-02T21:56:27.256Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 20998.614,
#  'z_score': 4.713505536496852}
#
# Subtype: extreme_value
# Time: 2024-11-02T22:10:31.750Z
# Details:
# {'is_contract': False,
#  'to': '0x77c9e6dc2fdcb14140a37e8f7408c08b95adaf76',
#  'value': 18585.799155,
#  'z_score': 4.1425229508083685}
#
# Subtype: extreme_value
# Time: 2024-11-03T04:08:17.383Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 24498.151965,
#  'z_score': 5.541656623229208}
#
# Subtype: extreme_value
# Time: 2024-11-03T06:10:16.969Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 19247.921,
#  'z_score': 4.299211328237068}
#
# Subtype: extreme_value
# Time: 2024-11-08T11:45:13.318Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 18723.306,
#  'z_score': 4.1750633730751945}
#
# Subtype: extreme_value
# Time: 2024-11-10T07:46:19.849Z
# Details:
# {'is_contract': False,
#  'to': '0x7018edc0331f2a4f3a4b0b851932523b87eaddcd',
#  'value': 14378.15974,
#  'z_score': 3.146802604591137}
#
# Subtype: extreme_value
# Time: 2024-11-10T19:47:06.427Z
# Details:
# {'is_contract': False,
#  'to': '0x8465eb1ea85631c55e09cac10f43a973561d3edc',
#  'value': 96118.07261,
#  'z_score': 22.490212606059327}
#
# Subtype: extreme_value
# Time: 2024-11-11T07:13:23.233Z
# Details:
# {'is_contract': False,
#  'to': '0x19f00b3a7b6f55c9da966fe3723251784a797fa7',
#  'value': 30947.6685,
#  'z_score': 7.067907854328098}
#
# Subtype: extreme_value
# Time: 2024-11-14T23:33:54.315Z
# Details:
# {'is_contract': False,
#  'to': '0xeba88149813bec1cccccfdb0dacefaaa5de94cb1',
#  'value': 52499.537965,
#  'z_score': 12.168068017486563}
#
# Subtype: extreme_value
# Time: 2024-11-15T10:15:13.472Z
# Details:
# {'is_contract': False,
#  'to': '0xdf6c66195d52cf8e6bcfb0afa1a5114fa18025c2',
# ...
# Time: 2024-10-28T12:12:35.057Z
# Details:
# {'time_diff': 2.002969444444444,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.705149401855078}
#
# Subtype: unusual_timing
# Time: 2024-10-28T23:05:11.219Z
# Details:
# {'time_diff': 1.8307263888888887,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.2998772609638336}
#
# Subtype: unusual_timing
# Time: 2024-10-29T08:28:42.321Z
# Details:
# {'time_diff': 1.9562891666666666,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.595314981817772}
#
# Subtype: unusual_timing
# Time: 2024-11-05T13:51:37.594Z
# Details:
# {'time_diff': 2.169886111111111,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 4.097889037321028}
#
# Subtype: unusual_timing
# Time: 2024-11-07T07:56:08.598Z
# Details:
# {'time_diff': 3.0762466666666666,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 6.230472447343623}
#
# Subtype: unusual_timing
# Time: 2024-11-07T11:13:17.041Z
# Details:
# {'time_diff': 2.0872941666666667,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.903557753325811}
#
# Subtype: unusual_timing
# Time: 2024-11-08T18:45:57.842Z
# Details:
# {'time_diff': 2.5736225,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 5.047843798358839}
#
# Subtype: unusual_timing
# Time: 2024-11-09T02:08:11.650Z
# Details:
# {'time_diff': 1.9832275,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.6586984139499354}
#
# Subtype: unusual_timing
# Time: 2024-11-09T20:37:36.069Z
# Details:
# {'time_diff': 2.222421388888889,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 4.221499736333791}
#
# Subtype: unusual_timing
# Time: 2024-11-10T03:46:14.682Z
# Details:
# {'time_diff': 2.855586111111111,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 5.711278361568668}
#
# Subtype: unusual_timing
# Time: 2024-11-12T06:37:07.629Z
# Details:
# {'time_diff': 1.8755902777777778,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.4054378842357687}
#
# Subtype: unusual_timing
# Time: 2024-11-12T23:47:40.417Z
# Details:
# {'time_diff': 2.2769669444444447,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 4.349840434916977}
#
# Subtype: unusual_timing
# Time: 2024-11-14T15:19:06.541Z
# Details:
# {'time_diff': 2.5868977777777777,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 5.07907931161987}
#
# Subtype: unusual_timing
# Time: 2024-11-15T19:22:20.502Z
# Details:
# {'time_diff': 2.1107441666666666,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.958733456481137}
#
# Subtype: unusual_timing
# Time: 2024-11-16T03:18:31.585Z
# Details:
# {'time_diff': 1.8664283333333334,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.383880667732901}
#
# Subtype: unusual_timing
# Time: 2024-11-16T20:35:18.578Z
# Details:
# {'time_diff': 1.8070980555555556,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.24428195580157}
#
# Subtype: unusual_timing
# Time: 2024-11-18T15:20:35.973Z
# Details:
# {'time_diff': 1.740013611111111,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.086438399596596}
#
# Subtype: unusual_timing
# Time: 2024-11-19T10:09:50.999Z
# Details:
# {'time_diff': 1.9079725,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.4816302885361163}
#
# Subtype: unusual_timing
# Time: 2024-11-22T16:38:57.300Z
# Details:
# {'time_diff': 1.7823255555555557,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.1859945312209597}
#
# Subtype: unusual_timing
# Time: 2024-11-24T09:26:32.401Z
# Details:
# {'time_diff': 2.0179980555555557,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.7405103479319877}
#
# Subtype: unusual_timing
# Time: 2024-11-24T22:15:33.317Z
# Details:
# {'time_diff': 2.112335,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.9624765416738703}
#
# Subtype: unusual_timing
# Time: 2024-11-25T19:30:10.780Z
# Details:
# {'time_diff': 2.135938888888889,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 4.018014331296244}
#
# Subtype: unusual_timing
# Time: 2024-11-26T08:08:36.959Z
# Details:
# {'time_diff': 1.823126388888889,
#  'usual_time_diff': 0.42825904648344565,
#  'z_score': 3.2819951567429184}
#
# PATTERN ANOMALIES:
#
# Subtype: long_sequence
# Details:
# {'avg_length': 10.920529801324504}
#
# Comparative Analysis:
# ------------------------------
# Contract Anomaly Score: 0.5541
# Wallet Anomaly Score: 0.5283
#
# Wallet anomalies by type:
# {'pattern': 1, 'temporal': 87, 'value': 72}
#
# Temporal Anomaly Analysis:
#
# Timestamp: 2024-08-29T21:32:32.106Z
# Time difference: 2.01 hours
# Z-score: 3.72
#
# Timestamp: 2024-08-30T13:14:15.414Z
# Time difference: 1.89 hours
# Z-score: 3.44
#
# Timestamp: 2024-08-31T03:26:40.347Z
# Time difference: 1.83 hours
# Z-score: 3.29
#
# Timestamp: 2024-08-31T19:57:31.485Z
# Time difference: 2.50 hours
# Z-score: 4.87
#
# Timestamp: 2024-09-01T07:37:42.012Z
# Time difference: 1.76 hours
# Z-score: 3.13
#
# Timestamp: 2024-09-03T19:26:56.670Z
# Time difference: 2.04 hours
# Z-score: 3.78
#
# Timestamp: 2024-09-04T21:29:19.817Z
# Time difference: 2.38 hours
# Z-score: 4.60
#
# Timestamp: 2024-09-05T17:01:41.464Z
# Time difference: 2.46 hours
# Z-score: 4.79
#
# Timestamp: 2024-09-06T03:31:44.701Z
# Time difference: 2.16 hours
# Z-score: 4.07
#
# Timestamp: 2024-09-06T05:52:18.165Z
# Time difference: 1.80 hours
# Z-score: 3.22
#
# Timestamp: 2024-09-07T04:29:28.717Z
# Time difference: 1.94 hours
# Z-score: 3.56
#
# Timestamp: 2024-09-08T21:28:26.002Z
# Time difference: 2.21 hours
# Z-score: 4.20
#
# Timestamp: 2024-09-10T01:06:44.695Z
# Time difference: 2.02 hours
# Z-score: 3.75
#
# Timestamp: 2024-09-10T06:21:30.191Z
# Time difference: 2.07 hours
# Z-score: 3.87
#
# Timestamp: 2024-09-11T05:28:34.257Z
# Time difference: 1.91 hours
# Z-score: 3.49
#
# Timestamp: 2024-09-11T09:42:39.404Z
# Time difference: 1.99 hours
# Z-score: 3.68
#
# Timestamp: 2024-09-11T16:39:09.828Z
# Time difference: 2.63 hours
# Z-score: 5.18
#
# Timestamp: 2024-09-11T20:48:34.615Z
# Time difference: 1.76 hours
# Z-score: 3.13
#
# Timestamp: 2024-09-12T06:18:33.137Z
# Time difference: 2.10 hours
# Z-score: 3.94
#
# Timestamp: 2024-09-12T09:17:10.839Z
# Time difference: 2.53 hours
# Z-score: 4.94
#
# Timestamp: 2024-09-13T01:28:01.195Z
# Time difference: 2.50 hours
# Z-score: 4.87
#
# Timestamp: 2024-09-13T12:44:13.525Z
# Time difference: 1.78 hours
# Z-score: 3.18
#
# Timestamp: 2024-09-13T15:25:30.574Z
# Time difference: 2.69 hours
# Z-score: 5.32
#
# Timestamp: 2024-09-16T12:07:25.808Z
# Time difference: 2.26 hours
# Z-score: 4.31
#
# Timestamp: 2024-09-20T06:36:14.480Z
# Time difference: 2.78 hours
# Z-score: 5.54
#
# Timestamp: 2024-09-20T09:50:33.118Z
# Time difference: 1.79 hours
# Z-score: 3.19
#
# Timestamp: 2024-09-20T19:14:29.274Z
# Time difference: 1.76 hours
# Z-score: 3.13
#
# Timestamp: 2024-09-22T01:59:37.370Z
# Time difference: 2.06 hours
# Z-score: 3.83
#
# Timestamp: 2024-09-22T13:41:39.817Z
# Time difference: 1.74 hours
# Z-score: 3.08
#
# Timestamp: 2024-09-23T08:55:35.942Z
# Time difference: 1.76 hours
# Z-score: 3.14
#
# Timestamp: 2024-09-24T13:05:37.613Z
# Time difference: 3.71 hours
# Z-score: 7.71
#
# Timestamp: 2024-09-26T07:21:43.089Z
# Time difference: 2.16 hours
# Z-score: 4.08
#
# Timestamp: 2024-09-27T07:25:24.927Z
# Time difference: 1.90 hours
# Z-score: 3.46
#
# Timestamp: 2024-09-27T18:23:13.997Z
# Time difference: 2.52 hours
# Z-score: 4.92
#
# Timestamp: 2024-09-29T02:15:44.928Z
# Time difference: 2.03 hours
# Z-score: 3.77
#
# Timestamp: 2024-09-29T05:20:10.138Z
# Time difference: 2.02 hours
# Z-score: 3.75
#
# Timestamp: 2024-09-29T16:12:43.770Z
# Time difference: 1.79 hours
# Z-score: 3.20
#
# Timestamp: 2024-09-30T07:43:42.040Z
# Time difference: 2.48 hours
# Z-score: 4.83
#
# Timestamp: 2024-10-01T08:41:41.017Z
# Time difference: 2.18 hours
# Z-score: 4.12
#
# Timestamp: 2024-10-05T19:33:13.455Z
# Time difference: 1.75 hours
# Z-score: 3.11
#
# Timestamp: 2024-10-09T21:00:22.182Z
# Time difference: 2.06 hours
# Z-score: 3.84
#
# Timestamp: 2024-10-10T02:31:52.669Z
# Time difference: 1.74 hours
# Z-score: 3.08
#
# Timestamp: 2024-10-10T07:53:42.149Z
# Time difference: 2.49 hours
# Z-score: 4.85
#
# Timestamp: 2024-10-13T08:00:35.079Z
# Time difference: 2.68 hours
# Z-score: 5.30
#
# Timestamp: 2024-10-15T17:24:41.525Z
# Time difference: 1.92 hours
# Z-score: 3.51
#
# Timestamp: 2024-10-15T23:05:03.515Z
# Time difference: 2.21 hours
# Z-score: 4.19
#
# Timestamp: 2024-10-17T02:39:22.113Z
# Time difference: 2.78 hours
# Z-score: 5.53
#
# Timestamp: 2024-10-18T04:10:36.614Z
# Time difference: 1.89 hours
# Z-score: 3.44
#
# Timestamp: 2024-10-18T09:30:18.643Z
# Time difference: 2.20 hours
# Z-score: 4.16
#
# Timestamp: 2024-10-19T00:02:10.389Z
# Time difference: 1.71 hours
# Z-score: 3.02
#
# Timestamp: 2024-10-20T22:34:23.772Z
# Time difference: 1.73 hours
# Z-score: 3.07
#
# Timestamp: 2024-10-21T11:02:40.954Z
# Time difference: 2.22 hours
# Z-score: 4.22
#
# Timestamp: 2024-10-21T13:07:16.674Z
# Time difference: 2.08 hours
# Z-score: 3.88
#
# Timestamp: 2024-10-22T08:26:18.389Z
# Time difference: 2.02 hours
# Z-score: 3.74
#
# Timestamp: 2024-10-23T01:26:15.467Z
# Time difference: 1.72 hours
# Z-score: 3.05
#
# Timestamp: 2024-10-23T08:11:04.334Z
# Time difference: 1.99 hours
# Z-score: 3.68
#
# Timestamp: 2024-10-23T12:06:40.916Z
# Time difference: 2.11 hours
# Z-score: 3.96
#
# Timestamp: 2024-10-23T17:05:07.115Z
# Time difference: 2.81 hours
# Z-score: 5.62
#
# Timestamp: 2024-10-24T03:06:11.764Z
# Time difference: 1.80 hours
# Z-score: 3.22
#
# Timestamp: 2024-10-24T08:56:13.634Z
# Time difference: 1.81 hours
# Z-score: 3.26
#
# Timestamp: 2024-10-25T10:49:06.701Z
# Time difference: 2.13 hours
# Z-score: 4.00
#
# Timestamp: 2024-10-25T15:24:38.626Z
# Time difference: 2.03 hours
# Z-score: 3.77
#
# Timestamp: 2024-10-26T15:59:50.406Z
# Time difference: 1.74 hours
# Z-score: 3.08
#
# Timestamp: 2024-10-27T08:22:04.754Z
# Time difference: 1.74 hours
# Z-score: 3.10
#
# Timestamp: 2024-10-28T12:12:35.057Z
# Time difference: 2.00 hours
# Z-score: 3.71
#
# Timestamp: 2024-10-28T23:05:11.219Z
# Time difference: 1.83 hours
# Z-score: 3.30
#
# Timestamp: 2024-10-29T08:28:42.321Z
# Time difference: 1.96 hours
# Z-score: 3.60
#
# Timestamp: 2024-11-05T13:51:37.594Z
# Time difference: 2.17 hours
# Z-score: 4.10
#
# Timestamp: 2024-11-07T07:56:08.598Z
# Time difference: 3.08 hours
# Z-score: 6.23
#
# Timestamp: 2024-11-07T11:13:17.041Z
# Time difference: 2.09 hours
# Z-score: 3.90
#
# Timestamp: 2024-11-08T18:45:57.842Z
# Time difference: 2.57 hours
# Z-score: 5.05
#
# Timestamp: 2024-11-09T02:08:11.650Z
# Time difference: 1.98 hours
# Z-score: 3.66
#
# Timestamp: 2024-11-09T20:37:36.069Z
# Time difference: 2.22 hours
# Z-score: 4.22
#
# Timestamp: 2024-11-10T03:46:14.682Z
# Time difference: 2.86 hours
# Z-score: 5.71
#
# Timestamp: 2024-11-12T06:37:07.629Z
# Time difference: 1.88 hours
# Z-score: 3.41
#
# Timestamp: 2024-11-12T23:47:40.417Z
# Time difference: 2.28 hours
# Z-score: 4.35
#
# Timestamp: 2024-11-14T15:19:06.541Z
# Time difference: 2.59 hours
# Z-score: 5.08
#
# Timestamp: 2024-11-15T19:22:20.502Z
# Time difference: 2.11 hours
# Z-score: 3.96
#
# Timestamp: 2024-11-16T03:18:31.585Z
# Time difference: 1.87 hours
# Z-score: 3.38
#
# Timestamp: 2024-11-16T20:35:18.578Z
# Time difference: 1.81 hours
# Z-score: 3.24
#
# Timestamp: 2024-11-18T15:20:35.973Z
# Time difference: 1.74 hours
# Z-score: 3.09
#
# Timestamp: 2024-11-19T10:09:50.999Z
# Time difference: 1.91 hours
# Z-score: 3.48
#
# Timestamp: 2024-11-22T16:38:57.300Z
# Time difference: 1.78 hours
# Z-score: 3.19
#
# Timestamp: 2024-11-24T09:26:32.401Z
# Time difference: 2.02 hours
# Z-score: 3.74
#
# Timestamp: 2024-11-24T22:15:33.317Z
# Time difference: 2.11 hours
# Z-score: 3.96
#
# Timestamp: 2024-11-25T19:30:10.780Z
# Time difference: 2.14 hours
# Z-score: 4.02
#
# Timestamp: 2024-11-26T08:08:36.959Z
# Time difference: 1.82 hours
# Z-score: 3.28
#
# Value Anomaly Analysis:
#
# Value: 19318.614
# Z-score: 4.32
# To contract: False
#
# Value: 42890.61742
# Z-score: 9.89
# To contract: False
#
# Value: 20998.845
# Z-score: 4.71
# To contract: False
#
# Value: 27999.384
# Z-score: 6.37
# To contract: False
#
# Value: 47426.739255
# Z-score: 10.97
# To contract: False
#
# Value: 30804.804065
# Z-score: 7.03
# To contract: False
#
# Value: 21163.575965
# Z-score: 4.75
# To contract: False
#
# Value: 14280.0
# Z-score: 3.12
# To contract: False
#
# Value: 19249.40878
# Z-score: 4.30
# To contract: False
#
# Value: 15609.307
# Z-score: 3.44
# To contract: False
#
# Value: 23645.15979
# Z-score: 5.34
# To contract: False
#
# Value: 16449.384
# Z-score: 3.64
# To contract: False
#
# Value: 24497.998
# Z-score: 5.54
# To contract: False
#
# Value: 17499.384
# Z-score: 3.89
# To contract: False
#
# Value: 20298.768
# Z-score: 4.55
# To contract: False
#
# Value: 51932.875015
# Z-score: 12.03
# To contract: False
#
# Value: 18708.34245
# Z-score: 4.17
# To contract: False
#
# Value: 15693.24001
# Z-score: 3.46
# To contract: False
#
# Value: 35000.0
# Z-score: 8.03
# To contract: False
#
# Value: 14686.707
# Z-score: 3.22
# To contract: False
#
# Value: 28515.530715
# Z-score: 6.49
# To contract: False
#
# Value: 15049.23
# Z-score: 3.31
# To contract: False
#
# Value: 13998.768
# Z-score: 3.06
# To contract: False
#
# Value: 17263.894795
# Z-score: 3.83
# To contract: False
#
# Value: 16282.517405
# Z-score: 3.60
# To contract: False
#
# Value: 15079.35527
# Z-score: 3.31
# To contract: False
#
# Value: 13885.75986
# Z-score: 3.03
# To contract: False
#
# Value: 14695.866675
# Z-score: 3.22
# To contract: False
#
# Value: 35987.66976
# Z-score: 8.26
# To contract: False
#
# Value: 52498.614
# Z-score: 12.17
# To contract: False
#
# Value: 17499.153
# Z-score: 3.89
# To contract: False
#
# Value: 24464.384
# Z-score: 5.53
# To contract: False
#
# Value: 24500.0
# Z-score: 5.54
# To contract: False
#
# Value: 47427.775885
# Z-score: 10.97
# To contract: False
#
# Value: 34999.307
# Z-score: 8.03
# To contract: False
#
# Value: 31499.307
# Z-score: 7.20
# To contract: False
#
# Value: 17835.23476
# Z-score: 3.96
# To contract: False
#
# Value: 27999.461
# Z-score: 6.37
# To contract: False
#
# Value: 20325.63841
# Z-score: 4.55
# To contract: False
#
# Value: 18774.545615
# Z-score: 4.19
# To contract: False
#
# Value: 13999.461
# Z-score: 3.06
# To contract: False
#
# Value: 26797.703135
# Z-score: 6.09
# To contract: False
#
# Value: 36006.903835
# Z-score: 8.27
# To contract: False
#
# Value: 93658.691
# Z-score: 21.91
# To contract: False
#
# Value: 13775.14061
# Z-score: 3.00
# To contract: False
#
# Value: 17501.18489
# Z-score: 3.89
# To contract: False
#
# Value: 20455.561
# Z-score: 4.58
# To contract: False
#
# Value: 17471.58539
# Z-score: 3.88
# To contract: False
#
# Value: 73534.075965
# Z-score: 17.15
# To contract: False
#
# Value: 17848.383
# Z-score: 3.97
# To contract: False
#
# Value: 21958.075965
# Z-score: 4.94
# To contract: False
#
# Value: 20998.614
# Z-score: 4.71
# To contract: False
#
# Value: 18585.799155
# Z-score: 4.14
# To contract: False
#
# Value: 24498.151965
# Z-score: 5.54
# To contract: False
#
# Value: 19247.921
# Z-score: 4.30
# To contract: False
#
# Value: 18723.306
# Z-score: 4.18
# To contract: False
#
# Value: 14378.15974
# Z-score: 3.15
# To contract: False
#
# Value: 96118.07261
# Z-score: 22.49
# To contract: False
#
# Value: 30947.6685
# Z-score: 7.07
# To contract: False
#
# Value: 52499.537965
# Z-score: 12.17
# To contract: False
#
# Value: 59038.813295
# Z-score: 13.72
# To contract: False
#
# Value: 14106.258425
# Z-score: 3.08
# To contract: False
#
# Value: 18136.523965
# Z-score: 4.04
# To contract: False
#
# Value: 16672.080985
# Z-score: 3.69
# To contract: False
#
# Value: 23065.0
# Z-score: 5.20
# To contract: False
#
# Value: 15718.341625
# Z-score: 3.46
# To contract: False
#
# Value: 17497.69
# Z-score: 3.89
# To contract: False
#
# Value: 32829.314
# Z-score: 7.51
# To contract: False
#
# Value: 95475.939335
# Z-score: 22.34
# To contract: False
#
# Value: 36718.72176
# Z-score: 8.43
# To contract: False
#
# Value: 15317.880235
# Z-score: 3.37
# To contract: False
#
# Value: 17498.306
# Z-score: 3.89
# To contract: False
#
# Analyzing wallet...
#
# Analyzing anomalies for address: 0x39cf2e49ea4d620e77d67088a8d815348e0abdf6
# ==================================================
#
# Anomaly Score: 0.5750
# Is Anomalous: True
#
# No anomalies detected
#
# Comparative Analysis:
# ------------------------------
# Contract Anomaly Score: 0.5541
# Wallet Anomaly Score: 0.5750
#
# Wallet anomalies by type:
# {}
#
# Analyzing wallet...
#
# Analyzing anomalies for address: 0xa1b1bbb8070df2450810b8eb2425d543cfcef79b
# ==================================================
#
# Anomaly Score: 0.4458
# Is Anomalous: False
#
# No anomalies detected
#
# Comparative Analysis:
# ------------------------------
# Contract Anomaly Score: 0.5541
# Wallet Anomaly Score: 0.4458
#
# Wallet anomalies by type:
# {}
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
